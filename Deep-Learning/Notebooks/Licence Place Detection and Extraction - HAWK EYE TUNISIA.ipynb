# %% [markdown]
# # Licence Place Detection and Extraction with Deep Learning model

# %% [markdown]
# This module is used to detect the presence of a licence plate in the photo and extract it.
# In this module, we used a pretrained model that can detect the presence of the tunisian licence plate with the weights file named "lapi.weights" published on github by the tunisian AI researcher Achref Khasri.
#
# Use case:
#
# - The main objective of this module is to extract the licence plate (LP) from the input image and to send a cropped image of it to the module that will recognise its characters.
#
# - The second objective is to prepare a dataset containing the licence plates cropped for the data enrichment module that is necessary to improve the model training.

# %% [markdown]
# !!! Note: You should verify every path in this file before using it.

# %% [markdown]
# ## Import of necessary libraries

# %%
import argparse
import sys
import cv2
import matplotlib.pyplot as plt
import numpy as np
from numpy import argmax,uint8
import os.path
from cv2.dnn import readNetFromDarknet,DNN_BACKEND_OPENCV,DNN_TARGET_CPU,NMSBoxes,blobFromImage
from cv2 import imwrite,rectangle,FILLED,putText,FONT_HERSHEY_SIMPLEX,getTextSize,VideoCapture,VideoWriter,VideoWriter_fourcc,CAP_PROP_FRAME_WIDTH,waitKey,getTickFrequency
import glob
from pathlib import Path

# %% [markdown]
# ## 1- Licence Plate Detection - YOLO : Deep Learning object detection architecture

# %% [markdown]
# In order to detect licence we will use Yolo ( You Only Look Once ) deep learning object detection architecture
# based on convolution neural networks.
# This architecture was introduced by Joseph Redmon , Ali Farhadi, Ross Girshick and Santosh Divvala first version in 2015 and later version 2 and 3.
#
# Yolo v1 : Paper [link](https://arxiv.org/pdf/1506.02640.pdf).
#
# Yolo v2 : Paper [link](https://arxiv.org/pdf/1612.08242.pdf).
#
# Yolo v3 : Paper [link](https://arxiv.org/pdf/1804.02767.pdf).
#
# Yolo is a single network trained end to end to perform a regression task predicting both object bounding box and object class.
# This network is extremely fast, it processes images in real-time at 45 frames per second. A smaller version of the network, tiny YOLO, processes an astounding 155 frames per second.
#
# You will find more information about how to train Yolo on your customized dataset in this [Link](https://towardsdatascience.com/automatic-license-plate-detection-recognition-using-deep-learning-624def07eaaf).
#
# There is also other Deep learning object detector that you can use such as Single Shot Detector (SSD) and Faster RCNN.

# %%
# Initialize the parameters
confThreshold = 0.5  #Confidence threshold
nmsThreshold = 0.4  #Non-maximum suppression threshold

inpWidth = 416  #608     #Width of network's input image
inpHeight = 416 #608     #Height of network's input image

directory="D:\\Hawk_Eye_version_1.0_LP_recog\\Hawk_Eye_version_1.0_LP_recog\\"

"""

#If the image is given as a parameter via the command line $python script.py --image=path 

parser = argparse.ArgumentParser(description='Licence Plate Detection using YOLO in OPENCV')
parser.add_argument('--image', help='Path to image file.')
#parser.add_argument('--video', help='Path to video file.') #this case is not defined in the function
args = parser.parse_args()


"""
# Load names of classes
classesFile = "D:\\Hawk_Eye_version_1.0_LP_recog\\Hawk_Eye_version_1.0_LP_recog\\Licence_plate_detection\\classes.names";

classes = None
with open(classesFile, 'rt') as f:
    classes = f.read().rstrip('\n').split('\n')

# Give the configuration and weight files for the model and load the network using them.

modelConfiguration = directory+"Licence_plate_detection\\darknet-yolov3.cfg";
modelWeights = directory+"Licence_plate_detection\\lapi.weights";

net = readNetFromDarknet(modelConfiguration, modelWeights)
net.setPreferableBackend(DNN_BACKEND_OPENCV)
net.setPreferableTarget(DNN_TARGET_CPU)

# %%
# Get the names of the output layers
def getOutputsNames(net):
    # Get the names of all the layers in the network
    layersNames = net.getLayerNames()
    # Get the names of the output layers, i.e. the layers with unconnected outputs
    return [layersNames[i[0] - 1] for i in net.getUnconnectedOutLayers()]

# %%
# Draw the predicted bounding box
def drawPred(classId, conf, left, top, right, bottom,frame):
    # Draw a bounding box.
    #    cv.rectangle(frame, (left, top), (right, bottom), (255, 178, 50), 3)
    global LP_extracted
    LP_extracted=frame[top+6:bottom-6, left+6:right-6]
    imwrite(directory+"Licence_Plate_extracted.jpg",LP_extracted)     	#extracting the licence plate
    
    rectangle(frame, (left, top), (right, bottom), (128, 190, 82), 3) #141, 214, 88
    label = '%.2f' % conf

    # Get the label for the class name and its confidence
    if classes:
        assert(classId < len(classes))
        label = '%s:%s' % (classes[classId], label)

    #Display the label at the top of the bounding box
    labelSize, baseLine = getTextSize(label, FONT_HERSHEY_SIMPLEX, 0.5, 1)
    top = max(top, labelSize[1])

    rectangle(frame, (left, top - round(1.5*labelSize[1])), (left + round(1.5*labelSize[0]), top + baseLine), (128, 190, 82), FILLED)
    #cv.rectangle(frame, (left, top - round(1.5*labelSize[1])), (left + round(1.5*labelSize[0]), top + baseLine),    (255, 255, 255), cv.FILLED)
    putText(frame, label, (left, top), FONT_HERSHEY_SIMPLEX, 0.75, (0,0,0), 2)
    #return(LP_extracted)

# %%
# Remove the bounding boxes with low confidence using non-maxima suppression
def postprocess(frame, outs):
    frameHeight = frame.shape[0]
    frameWidth = frame.shape[1]

    classIds = []
    confidences = []
    boxes = []
    # Scan through all the bounding boxes output from the network and keep only the
    # ones with high confidence scores. Assign the box's class label as the class with the highest score.
    classIds = []
    confidences = []
    boxes = []
    for out in outs:
        #print("out.shape : ", out.shape)
        for detection in out:
            #if detection[4]>0.001:
            scores = detection[5:]
            classId = argmax(scores)
            #if scores[classId]>confThreshold:
            confidence = scores[classId]
            #if detection[4]>confThreshold:
                #print(detection[4], " - ", scores[classId], " - th : ", confThreshold)
                #print(detection)
            if confidence > confThreshold:
                center_x = int(detection[0] * frameWidth)
                center_y = int(detection[1] * frameHeight)
                width = int(detection[2] * frameWidth)
                height = int(detection[3] * frameHeight)
                left = int(center_x - width / 2)
                top = int(center_y - height / 2)
                classIds.append(classId)
                confidences.append(float(confidence))
                boxes.append([left, top, width, height])

    # Perform non maximum suppression to eliminate redundant overlapping boxes with
    # lower confidences.
    indices = NMSBoxes(boxes, confidences, confThreshold, nmsThreshold)
    #print("indices",type(indices))
    for i in indices:
        i = i[0]
        box = boxes[i]
        left = box[0]
        top = box[1]
        width = box[2]
        height = box[3]
        drawPred(classIds[i], confidences[i], left, top, left + width, top + height,frame)
        #print("i=",i)
        #print("box=",box)
        #PLicence=drawPred(classIds[i], confidences[i], left, top, left + width, top + height,frame)
    return(top) #added to know where we will put the text in the final image

# %%
def LP_detection(image):
    
    """
    :param:
    the path of the vehicle image
    
    :return:
    * if the licence plate exists in the photo, this function returns these parameters:
        - LP_extracted : is the photo of the licence plate cropped 
        - frame.astype(uint8) : a new photo same as the input photo but containing a green box showing the presence of the LP 
        and indicating the score of the detection.
        - top: is the top coordinate of the box, used in the recognition file to write on the photo the result of the licence plate
        recognition.
        
    * else: this function returns None, None, None, which should be tested in the main script to interrupt the process before 
    the recognition.
        
    """
    
    if (image is not None):
        print(image)
        cap = VideoCapture(image)
        hasFrame, frame = cap.read()
        
        # Create a 4D blob from a frame. 
        blob = blobFromImage(frame, 1/255, (inpWidth, inpHeight), [0,0,0], 1, crop=False)

        # Sets the input to the network
        net.setInput(blob)

        # Runs the forward pass to get output of the output layers
        outs = net.forward(getOutputsNames(net))

        # Remove the bounding boxes with low confidence
        #postprocess(frame, outs)
        try:
            top=postprocess(frame, outs)

            # Put efficiency information. The function getPerfProfile returns the overall time for inference(t) and the timings for each of the layers(in layersTimes)
            t, _ = net.getPerfProfile()
            label = 'Inference time: %.2f ms' % (t * 1000.0 / getTickFrequency())
            #cv.putText(frame, label, (0, 15), cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255))


            return LP_extracted ,frame.astype(uint8),top
        except:
            return None,None,None   #in this case, we don't have a licence plate in the photo

# %%
#Test of the LP extraction
img= 'C:\\Users\\PC\\Desktop\\win2.png'
a,b,c=LP_detection(img)
if(a is not None and b is not None and c is not None):
    cv2.imwrite("C:\\Users\\PC\\Desktop\\extracted.jpg",a)
else:
    print("no lp")
# Out:
# C:\Users\PC\Desktop\win2.png
# indices <class 'numpy.ndarray'>

# %% [markdown]
# # 2- Extracting licence plates to prepare the dataset

# %% [markdown]
# We can use the script to prepare a dataset containing the licence plates.

# %%
vehicle_folder="D:\\STAGE CHAMBI EAGLE\\datasets\\instadeep hackathon\\license_plates_detection_train\\license_plates_detection_train" #the folder containing the vehicles
LP_folder="D:\\STAGE CHAMBI EAGLE\\datasets\\LP_TN" #the output folder containing the LP extracted 

def extracting_LP(vehicle_folder,LP_folder):
    
    """
    :input: the folder containing the vehicles photos

    :output: the folder that contains the result of cropping
    
    """
    
    number_of_items=len(glob.glob("{}\\*".format(LP_folder)))+1
    
    for imagepath in glob.glob("{}\\*.*".format(vehicle_folder)):
        a,b,c=LP_detection(imagepath)
            
        if(a is not None and b is not None and c is not None):
            cv2.imwrite("{}\\{}.jpg".format(LP_folder,number_of_items),a)
            number_of_items+=1
        else: pass
extracting_LP(vehicle_folder,LP_folder)
# Out:
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\1.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\10.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\100.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\101.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\102.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\103.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\104.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\105.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\106.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\107.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\108.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\109.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\11.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\110.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\111.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\112.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\113.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\114.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\115.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\116.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\117.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\118.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\119.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\12.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\120.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\121.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\122.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\123.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\124.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\125.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\126.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\127.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\128.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\129.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\13.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\130.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\131.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\132.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\133.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\134.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\135.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\136.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\137.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\138.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\139.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\14.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\140.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\141.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\142.jpg
# indices <class 'tuple'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\143.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\144.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\145.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\146.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\147.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\148.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\149.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\15.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\150.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\151.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\152.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\153.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\154.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\155.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\156.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\157.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\158.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\159.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\16.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\160.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\161.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\162.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\163.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\164.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\165.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\166.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\167.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\168.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\169.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\17.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\170.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\171.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\172.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\173.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\174.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\175.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\176.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\177.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\178.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\179.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\18.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\180.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\181.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\182.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\183.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\184.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\185.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\186.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\187.jpg
# indices <class 'tuple'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\188.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\189.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\19.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\190.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\191.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\192.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\193.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\194.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\195.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\196.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\197.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\198.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\199.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\2.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\20.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\200.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\201.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\202.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\203.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\204.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\205.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\206.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\207.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\208.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\209.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\21.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\210.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\211.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\212.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\213.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\214.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\215.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\216.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\217.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\218.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\219.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\22.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\220.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\221.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\222.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\223.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\224.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\225.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\226.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\227.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\228.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\229.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\23.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\230.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\231.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\232.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\233.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\234.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\235.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\236.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\237.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\238.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\239.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\24.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\240.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\241.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\242.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\243.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\244.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\245.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\246.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\247.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\248.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\249.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\25.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\250.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\251.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\252.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\253.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\254.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\255.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\256.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\257.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\258.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\259.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\26.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\260.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\261.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\262.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\263.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\264.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\265.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\266.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\267.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\268.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\269.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\27.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\270.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\271.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\272.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\273.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\274.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\275.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\276.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\277.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\278.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\279.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\28.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\280.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\281.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\282.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\283.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\284.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\285.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\286.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\287.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\288.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\289.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\29.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\290.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\291.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\292.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\293.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\294.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\295.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\296.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\297.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\298.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\299.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\3.jpg
# indices <class 'tuple'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\30.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\300.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\301.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\302.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\303.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\304.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\305.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\306.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\307.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\308.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\309.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\31.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\310.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\311.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\312.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\313.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\314.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\315.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\316.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\317.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\318.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\319.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\32.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\320.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\321.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\322.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\323.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\324.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\325.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\326.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\327.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\328.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\329.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\33.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\330.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\331.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\332.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\333.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\334.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\335.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\336.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\337.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\338.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\339.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\34.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\340.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\341.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\342.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\343.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\344.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\345.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\346.jpg
# indices <class 'tuple'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\347.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\348.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\349.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\35.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\350.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\351.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\352.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\353.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\354.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\355.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\356.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\357.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\358.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\359.jpg
# indices <class 'tuple'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\36.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\360.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\361.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\362.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\363.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\364.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\365.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\366.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\367.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\368.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\369.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\37.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\370.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\371.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\372.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\373.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\374.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\375.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\376.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\377.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\378.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\379.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\38.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\380.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\381.jpg
# indices <class 'numpy.ndarray'>
# ...
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\816.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\817.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\818.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\819.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\82.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\820.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\821.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\822.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\823.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\824.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\825.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\826.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\827.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\828.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\829.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\83.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\830.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\831.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\832.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\833.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\834.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\835.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\836.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\837.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\838.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\839.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\84.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\840.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\841.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\842.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\843.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\844.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\845.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\846.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\847.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\848.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\849.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\85.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\850.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\851.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\852.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\853.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\854.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\855.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\856.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\857.jpg
# indices <class 'tuple'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\858.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\859.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\86.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\860.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\861.jpg
# indices <class 'tuple'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\862.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\863.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\864.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\865.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\866.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\867.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\868.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\869.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\87.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\870.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\871.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\872.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\873.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\874.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\875.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\876.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\877.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\878.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\879.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\88.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\880.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\881.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\882.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\883.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\884.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\885.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\886.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\887.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\888.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\889.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\89.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\890.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\891.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\892.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\893.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\894.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\895.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\896.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\897.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\898.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\899.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\9.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\90.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\900.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\91.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\92.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\93.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\94.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\95.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\96.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\97.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\98.jpg
# indices <class 'numpy.ndarray'>
# D:\STAGE CHAMBI EAGLE\datasets\instadeep hackathon\license_plates_detection_train\license_plates_detection_train\99.jpg
# indices <class 'numpy.ndarray'>

# %%
vehicle_folder="D:\\STAGE CHAMBI EAGLE\\datasets\\CAMERA ANPR COPY\\20160701\\" #the folder containing the vehicles
LP_folder="D:\\STAGE CHAMBI EAGLE\\datasets\\LP_TN" #the output folder containing the LP extracted 

def extracting_LP_nested_folders(vehicle_folder,LP_folder):
    """
    :input: the folder containing the folders containing the vehicles photos

    :output: the folder that contains the result of cropping
    
    In this function, we are doing the same thing as above but with nested folders like this example :
    
    ___ vehicle_folder:
        
        ______images000 :
    
            __________img1.jpg
            ...
            __________img200.jpg

        ______images001
        ...
        ______images048

    """  
    
    number_of_items=len(glob.glob("{}\\*".format(LP_folder)))+1
